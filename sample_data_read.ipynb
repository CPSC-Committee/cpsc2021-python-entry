# %%
import wfdb
import numpy as np 
import pandas as pd 
import neurokit2 as nk 
import matplotlib.pyplot as pyplot

# %% [markdown]
# The necessary data can be downloaded from :
# https://physionet.org/content/cpsc2021/1.0.0/Training_set_I/#files-panel

# %%
sample_record=wfdb.rdrecord("D:/RA/Project/Database/CPSC2021/Training_set_I/data_0_1",sampto=6000)
sample_record.__dict__
# Out:
# {'record_name': 'data_0_1',
#  'n_sig': 2,
#  'fs': 200,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 6000,
#  'base_time': None,
#  'base_date': None,
#  'comments': ['non atrial fibrillation'],
#  'sig_name': ['I', 'II'],
#  'p_signal': array([[-0.00754304, -0.29190688],
#         [ 0.01134075, -0.34900008],
#         [-0.0165266 , -0.28864668],
#         ...,
#         [-0.02228864, -0.20443819],
#         [-0.00798829, -0.19712263],
#         [-0.00861688, -0.19632746]]),
#  'd_signal': None,
#  'e_p_signal': None,
#  'e_d_signal': None,
#  'file_name': ['data_0_1.dat', 'data_0_1.dat'],
#  'fmt': ['16', '16'],
#  'samps_per_frame': [1, 1],
#  'skew': [None, None],
#  'byte_offset': [None, None],
#  'adc_gain': [38180.879946031266, 12575.928259223296],
#  'baseline': [-2839, -8838],
#  'units': ['mV', 'mV'],
#  'adc_res': [16, 16],
#  'adc_zero': [0, 0],
#  'init_value': [-3127, -12509],
#  'checksum': [19137, 47449],
#  'block_size': [0, 0]}

# %%
sample_annotate=wfdb.rdann("D:/RA/Project/Database/CPSC2021/Training_set_I/data_0_1","atr",sampto=6000)
sample_annotate.__dict__

# %%
wfdb.plot_wfdb(sample_record,sample_annotate,plot_sym=True,figsize=(15,4))

# %%
samples=wfdb.rdsamp("D:/RA/Project/Database/CPSC2021/Training_set_I/data_0_1")
samples
# Out:
# (array([[-0.00754304, -0.29190688],
#         [ 0.01134075, -0.34900008],
#         [-0.0165266 , -0.28864668],
#         ...,
#         [-0.02294342, -0.17660724],
#         [-0.01686708, -0.17819758],
#         [-0.06542542, -0.16682665]]),
#  {'fs': 200,
#   'sig_len': 208381,
#   'n_sig': 2,
#   'base_date': None,
#   'base_time': None,
#   'units': ['mV', 'mV'],
#   'sig_name': ['I', 'II'],
#   'comments': ['non atrial fibrillation']})
